# %%
import numpy
import pandas as pd
import talib
from talib import MA_Type
from matplotlib import pyplot as plt 
from datetime import datetime
import plotly.graph_objects as go
#import quantmod as qm
from matplotlib import pyplot
from pandas import to_datetime
from pandas import DataFrame
from fbprophet import Prophet
from matplotlib import pyplot
import os
import numpy
import quandl


quandl.ApiConfig.api_key = 'yKriQrmZaVRpoZt3JkSN'
quandl.get('NASDAQOMX/NQSE35CAD', start_date='2021-07-16', end_date='2021-07-16')
df = quandl.get('NASDAQOMX/NQSE35CAD')

high, low, close, open = numpy.random.uniform(low=10.5, high=13.3, size=(1000,)), numpy.random.uniform(low=10.5, high=13.3, size=(1000,)), numpy.random.uniform(low=10.5, high=13.3, size=(1000,)), numpy.random.uniform(low=10.5, high=13.3, size=(1000,))
#df = pd.read_csv(path, header=0)
#df = pd.read_csv('http://localhost:9999/files/notebook/StockAnalysis/Bitstamp_BTCUSD_2020_minute.csv?_xsrf=2%7Ca2892e56%7C4aa603b7aafd261f92082a6ff2e5869b%7C1626474746')

# %%
output = talib.SMA(close)
df.plot()
pyplot.show()
c = numpy.random.randn(100)
k, d = talib.STOCHRSI(c)

# %%
upper, middle, lower = talib.BBANDS(close, matype=MA_Type.T3)

# %%
RSI = talib.RSI(close, timeperiod=14)
print(RSI[-1])
# Out:
# 53.611923533292746

# %%
# Create an interactive candlestick plot with Plotly
fig = go.Figure(data=[go.Candlestick(x=df['trade_date'],
                open=open,
                high=high,
                low=low,
                close=close)])



# Plot the three lines of the Bollinger Bands indicator
for parameter in ['middle', 'lower', 'upper']:
    fig.add_trace(go.Scatter(
        x = df,
        y = parameter,
        showlegend = False,
        line_color = 'gray',
        mode='lines',
        line={'dash': 'dash'},
        marker_line_width=2, 
        marker_size=10,
        opacity = 0.8))
    
# Add title and format axes
fig.update_layout(
    title='Bitcoin price in the last 2 hours with Bollinger Bands',
    yaxis_title='BTC/USD')

fig.show()


# Add title and format axes
fig.update_layout(
    title='Bitcoin price in the last 2 hours as candlestick chart',
    yaxis_title='BTC/USD')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-24b5c8fa0f85> in <module>
#      11 for parameter in ['middle', 'lower', 'upper']:
#      12     fig.add_trace(go.Scatter(
# ---> 13         x = data,
#      14         y = parameter,
#      15         showlegend = False,
#
# NameError: name 'data' is not defined

# %%
x = upper 
y = lower
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
#result can be visualized by plotting the Bollinger Bands on top of our previous chart.

# Define the parameters for the Bollinger Band calculation
ma_size = 20
bol_size = 2

# Convert the timestamp data to a human readable format
btc_data.index = pd.to_datetime(btc_data.time, unit='ms')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-7b9276c5adfb> in <module>
#       2
#       3 # Create a working copy of the last 2 hours of the data
# ----> 4 btc_data = df.iloc[-240:].copy()
#       5
#       6 # Define the parameters for the Bollinger Band calculation
#
# NameError: name 'df' is not defined
