# %%
from pandas import read_csv

# %%
from matplotlib import pyplot
from pandas import to_datetime
from pandas import DataFrame
from fbprophet import Prophet
from matplotlib import pyplot
import os
import numpy

# %%
path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-car-sales.csv'

# %%
df = read_csv(path, header=0)

# %%
df.plot()
pyplot.show()
c = numpy.random.randn(100)
k, d = talib.STOCHRSI(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-521193c388db> in <module>
#       2 pyplot.show()
#       3 c = numpy.random.randn(100)
# ----> 4 k, d = talib.STOCHRSI(c)
#
# NameError: name 'talib' is not defined

# %%
df.columns = ['ds', 'y']
os.environ["NUMEXPR_MAX_THREADS"] = "4"
df['ds']= to_datetime(df['ds'])
# define the model
model = Prophet(weekly_seasonality=True,daily_seasonality=True)
# fit the model
model.fit(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# KeyError: 'metric_file'

# %%
# define the period for which we want a prediction
future = list()
for i in range(1, 13):
	date = '1968-%02d' % i
	future.append([date])
future = DataFrame(future)
future.columns = ['ds']
future['ds']= to_datetime(future['ds'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c81d807c0aad> in <module>
#       4         date = '1968-%02d' % i
#       5         future.append([date])
# ----> 6 future = DataFrame(future)
#       7 future.columns = ['ds']
#       8 future['ds']= to_datetime(future['ds'])
#
# NameError: name 'DataFrame' is not defined

# %%
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head())
# plot forecast
model.plot(forecast)
pyplot.show()
